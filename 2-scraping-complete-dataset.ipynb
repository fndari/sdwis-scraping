# %%
import pandas as pd
from config import PATH_URLS, N_URLS_TO_PROCESS

# change this number to set the number of URLs to process.
# Running the whole dataset can be somewhat slow (~10 minutes) and memory-intensive (~3 GB)
# since the processing, especially the parsing, is not really optimized for performance
N_URLS_TO_PROCESS = -1

URLS = pd.read_csv(PATH_URLS).head(N_URLS_TO_PROCESS)
URLS.head(10)
# Out:
#       pws_id  pws_url_id                                                url
# 0  CA0103040           3  https://sdwis.waterboards.ca.gov/PDWW/JSP/Wate...
# 1  CA0103041           4  https://sdwis.waterboards.ca.gov/PDWW/JSP/Wate...
# 2  CA0105002          15  https://sdwis.waterboards.ca.gov/PDWW/JSP/Wate...
# 3  CA0105003          16  https://sdwis.waterboards.ca.gov/PDWW/JSP/Wate...
# 4  CA0105008          18  https://sdwis.waterboards.ca.gov/PDWW/JSP/Wate...
# 5  CA0105009          19  https://sdwis.waterboards.ca.gov/PDWW/JSP/Wate...
# 6  CA0105010          20  https://sdwis.waterboards.ca.gov/PDWW/JSP/Wate...
# 7  CA0105012          22  https://sdwis.waterboards.ca.gov/PDWW/JSP/Wate...
# 8  CA0105013          23  https://sdwis.waterboards.ca.gov/PDWW/JSP/Wate...
# 9  CA0105016          26  https://sdwis.waterboards.ca.gov/PDWW/JSP/Wate...

# %% [markdown]
# # Fetching the HTML pages
#
# To get the data from the server, we need to issue a request for each WSD URL. The number is not enormous but at the same time non-negligible. since, in general, we want to throttle (limit the rate) our requests since we don't know if this will trigger some security response from the server, e.g. refusing connections.
#
# In addition, it's useful (especially when scraping) to be able to cache the results, so that we fetch the data once and can process it without limitations afterwards.

# %%
from config import PATH_REQUESTS_CACHE_DB

PATH_REQUESTS_CACHE_DB
# Out:
# PosixPath('/data/datasets/parse-pws')

# %%
import requests_cache
import time

def _make_throttle_hook(timeout=1):
    """
    Returns a response hook function which sleeps for `timeout` seconds if
    response is not coming from the cache.

    From https://requests-cache.readthedocs.io/en/latest/user_guide.html#usage
    """
    def hook(response, *args, **kwargs):
        if not getattr(response, 'from_cache', False):
            # TODO use logging instead of print
            print(f'{response} not found in cache. Timeout for {timeout:.2f} s.')
            time.sleep(timeout)
        return response
    return hook


def get_session(rate_max=.5, timeout=None, path_cache_db=''):
    """
    `rate_max` is in requests per second; `timeout` is in seconds.
    """
    timeout = timeout or 1 / rate_max
    
    # we create the cache backend object explicitly,
    # so that it's not overwritten every time we call this function
    # (which happens when re-running the notebook)
    from requests_cache.backends.sqlite import DbCache
    
    cache_db = DbCache(location=str(path_cache_db))

    s = requests_cache.CachedSession(backend=cache_db)
    s.hooks = {'response': _make_throttle_hook(timeout)}
    return s

# %%
CACHED_SESSION = get_session(timeout=.2, path_cache_db=PATH_REQUESTS_CACHE_DB)
CACHED_SESSION
# Out:
# <CachedSession(DbCache('cache', ...), expire_after=None, allowable_methods=('GET',))>

# %%
from tqdm._tqdm_notebook import tqdm_notebook

# %%
def fetch_urls(_df_urls, session):
    df = _df_urls.reset_index()

    with tqdm_notebook(total=len(df)) as progress_bar:
        for row in df.itertuples():
            progress_bar.set_postfix({'fetching PWSID': row.pws_id})
            progress_bar.update(1)
            
            resp = session.get(row.url)

# %%
fetch_urls(URLS, CACHED_SESSION)
# Out:
# HBox(children=(IntProgress(value=0, max=8327), HTML(value='')))

# %% [markdown]
# # Utility classes for parsing
#
# First, some generic base classes:

# %%
from requests_html import HTMLSession, HTML

# %%
class DocumentParser:
    """Helper class to process a single page/HTML document"""
        
    def __init__(self, html=None, **kwargs):
        self.html = html
        
    def to_record(self):
        return {}
    
    @staticmethod
    def get_fallback_html():
        return HTML(html='<body></body>')
    
    @classmethod
    def from_url(cls, url, session=None, **kwargs):
        session = session or HTMLSession()
        
        resp = session.get(url)
        if resp:
            if isinstance(session, HTMLSession):
                html = resp.html
            else:
                html = HTML(url=url, html=resp.text)
        else:
            html = cls.get_fallback_html()

        return cls(html=html, url=url, **kwargs)
    
    @classmethod
    def from_path(cls, path, **kwargs):
        html = HTML(html=Path(path).read_text())
        return cls(html=html, **kwargs)
    
    def to_path(self, path):
        path = Path(path)
        path.save_text(self.html.html)
        return path

# %%
class ComponentParser:
    """Helper class for parsing a (generalized) single component"""
    fallback = dict

    def __init__(self, element=None, html_raw=None, process=None, **kwargs):

        self.element = element
        self.html_raw = html_raw or self.element.html
        
        self.data = self.fallback()
        self.process = process or (lambda d: d)
        
        try:
            data = self.parse(**kwargs)
            data = self.process(data)
            self.data = data
        except Exception:
            pass

    def parse(self, **kwargs):
        return self.data
        
    def to_record(self):
        return dict(self.data)

# %% [markdown]
# Let's extend these with more specific subclasses for parsing WSD pages and the tables that appear there:

# %%
def extract_keyval_table(element, key_pattern=':'):
    keys = []
    values = []
    
    for table_row in element.find('td'):
        text = table_row.text
        if key_pattern in text:
            keys.append(text.replace(key_pattern, '').strip())
        else:
            values.append(text.strip())
    
    return dict(zip(keys, values))

class WSDetailsTable(ComponentParser):
    """Parses the table at the top op the page, which require a special treatment since it's not a well-formed HTML table"""
    fallback = dict
    
    def parse(self):
        return extract_keyval_table(self.element)
    
    def to_record(self):
        return dict(self.data)

class WSTable(ComponentParser):
    fallback = pd.DataFrame
    
    def parse(self):
        return pd.read_html(self.html_raw)[0]
    
    def to_record(self):

        # return self.data.to_dict(orient='records')
        # the DataFrame.to_dict(orient='records') mangles column names
        # e.g. "Type  Code" (with two spaces) shows up as "_1"
        # the same happens using df.itertuples()
        # it might be a pandas bug
        def to_dict_records_alt(d):
            # transform nans to None for greater compatibility
            # https://stackoverflow.com/a/39279898/
            return [dict(row) for i, row in d.where(d.notnull(), None).iterrows()]
        
        return to_dict_records_alt(self.data)

# %%
class PWSDetailsPage(DocumentParser):
    
    def __init__(self, url='', pws_id=None, **kwargs):
        super().__init__(**kwargs)

        self.url = url

#         if self.url:
#             self.parse_url(self.url)
#         else:
        self.pws_id = pws_id
        
    def parse_url(self, url):
        params = get_params_from_url(url)
        
        self.pws_id = params.get('wsnumber', '')
        self.pws_url_id = params.get('tinwsys_is_number', '')
        
    @property
    def table_details(self):
        sel = 'table[summary="Water System  Details"]'
        elem = self.html.find(sel, first=True)
        return WSDetailsTable(elem)
    
    @property
    def table_water_sources(self):
        sel = 'table[summary="Details about Sources of Water"]'
        # there are two elements with identical attributes (elem.attrs):
        # this ("Sources of water") is the first, "Water Purchases" is the second
        elem = self.html.find(sel, first=True)

        def rename_cols(d):
            # get rid of extra space
            return d.rename(columns={'Type  Code': 'Type Code'})

        return WSTable(elem, process=rename_cols)
    
    @property
    def table_water_purchases(self):
        sel = 'table[summary="Details about Sources of Water"]'
        elem = self.html.find(sel)[1]
        
        return WSTable(elem)
    
    @property
    def table_ws_contacts(self):
        pass
    
    @property
    def table_service_areas(self):
        sel = 'table[summary="Summary of Service Area"]'
        return WSTable(self.html.find(sel, first=True))
    
    @property
    def table_service_connections(self):
        sel = 'table[summary="Summary of Service Connection"]'
        return WSTable(self.html.find(sel, first=True))
    
    @property
    def urls_other(self):
        def is_interesting(url):
            # exclude:
            return all([
                # internal framework links
                'jsp' not in url,
                # google maps (might be useful for the address)
                'maps.google' not in url,
                # EAR links
                'drinc.ca.gov/ear/' not in url
            ])

        return [url for url in self.html.links if is_interesting(url)]
    
    def to_record(self):
        d = {'pws_id': self.pws_id}

        d['water_system_details'] = self.table_details.to_record()

        d['water_sources'] = self.table_water_sources.to_record()        
        d['water_purchases'] = self.table_water_purchases.to_record()
        d['service_areas'] = self.table_service_areas.to_record()
        d['service_connections'] = self.table_service_connections.to_record()
        
        d['urls_other'] = self.urls_other
        
        return d

# %% [markdown]
# Then, some utility functions to regularize field/column names and solidify the final data tables:

# %%
import re

def to_snakecase(s):
    import re
    
    # convert one or more spaces to underscore
    s = re.sub('\s+', '_', s.strip())
    # strip all other non-alphanumeric chars
    return (re.sub('\W', '', s)
            .lower()
           )

def normalize_column_names(df):
    return df.rename(columns=to_snakecase)

def drop_columns_robust(df, cols):
    to_drop = df.columns & set(cols)
    
    return df.drop(columns=to_drop)

def to_category(df, cols):
    return df.astype({col: 'category' for col in cols})

# %% [markdown]
# And, finally, a container class to interact with the whole dataset (or, a specified portion of it)

# %%
class WSDDataset:
    
    @classmethod
    def from_df_urls(cls, df_urls, **kwargs):
        return cls([PWSDetailsPage.from_url(**row, **kwargs) for _, row in df_urls.iterrows()])
    
    def __init__(self, items=None, records=None):
        self._items = items or []
        self._records = records or self.to_record()
        
    def __repr__(self):
        return f'{type(self).__name__}(len={len(self)})'
        
    def __iter__(self):
        return iter(self._items)
    
    def __len__(self):
        return len(self._items or self._records)
    
    def to_record(self):
        return [item.to_record() for item in self]
    
    @property
    def records(self):
        return self._records
    
    def _get_table_from_record_dict(self, field_name):
        return pd.DataFrame([dict(pws_id=r['pws_id'], **r[field_name]) for r in self.records])

    def _get_table_from_record_list(self, field_name, as_index=None):
        df = (pd.DataFrame([dict(pws_id=r['pws_id'], entry_id=entry_id, **field_data)
                         for r in self.records
                         for entry_id, field_data in enumerate(r[field_name])])
          )

        if as_index:
            df = df.set_index(as_index)
        return df
    
    def get_table_details(self):
        nuisance_cols = ['PG&E PHILBROOK DAM']

        return (self._get_table_from_record_dict('water_system_details')
                .set_index('pws_id')
                .pipe(drop_columns_robust, nuisance_cols)
                .pipe(normalize_column_names)
                .pipe(to_category, ['federal_type', 'primary_source', 'state_type', 'status'])
                .assign(activity_date=lambda d: pd.to_datetime(d['activity_date']))
               )
    
    def get_table_service_connections(self):
        return (self._get_table_from_record_list('service_connections', as_index=['pws_id', 'entry_id'])
                .pipe(normalize_column_names)
                .pipe(to_category, ['meter_type', 'type'])
               )
    
    def get_table_service_areas(self):
        return (self._get_table_from_record_list('service_areas', as_index=['pws_id', 'entry_id'])
                .pipe(normalize_column_names)
                .pipe(to_category, ['code', 'name'])
               )
    
    def get_table_water_sources(self):
        return (self._get_table_from_record_list('water_sources', as_index=['pws_id', 'entry_id'])
                .pipe(normalize_column_names)
                .pipe(to_category, ['status', 'type_code'])
               )
    
    def get_table_water_purchases(self):
        return (self._get_table_from_record_list('water_purchases', as_index=['pws_id', 'entry_id'])
                .pipe(normalize_column_names)
                .pipe(to_category, ['buyer_facility_type', 'seller_facility_type'])
               )
    
    def to_csv(self, path):

        names_functions = [
            ('details', self.get_table_details),
            ('service-connections', self.get_table_service_connections),
            ('service-areas', self.get_table_service_areas),
            ('water-sources', self.get_table_water_sources),
            ('water-purchases', self.get_table_water_purchases),
        ]
        
        for name, f in names_functions:
            path_file = (path / name).with_suffix('.csv')
            df = f()
            df.to_csv(path_file)
            
    def to_json(self, path):
        import json

        with (path / 'records.json').open('w') as f:
            json.dump(d.records, f, indent=4)

# %%
import numpy as np

s = pd.Series([1, 2, 3, np.nan])
dict(s.where(s.notnull(), None))
# Out:
# {0: 1.0, 1: 2.0, 2: 3.0, 3: None}

# %%
d = WSDDataset.from_df_urls(URLS, session=CACHED_SESSION)
d
# Out:
# WSDDataset(len=8327)

# %%
(d.get_table_details()
)
# Out:
#           1111 activity_date coachella_vwd_cove_community  \
# pws_id
# CA0103040  NaN    1983-01-27                          NaN
# CA0103041  NaN    1983-01-27                          NaN
# CA0105002  NaN    1981-11-30                          NaN
# CA0105003  NaN    1981-11-30                          NaN
# CA0105008  NaN    1981-11-30                          NaN
# CA0105009  NaN    2017-10-24                          NaN
# CA0105010  NaN    1984-01-21                          NaN
# CA0105012  NaN    1993-07-01                          NaN
# CA0105013  NaN    1993-07-01                          NaN
# CA0105016  NaN    2013-08-16                          NaN
# CA0105017  NaN    2015-07-02                          NaN
# CA0105018  NaN    2015-11-13                          NaN
# CA0105019  NaN    2018-02-01                          NaN
# CA0105020  NaN    1993-07-01                          NaN
# CA0110001  NaN    1979-03-22                          NaN
# CA0110003  NaN    1979-03-22                          NaN
# CA0110005  NaN    1979-03-22                          NaN
# CA0110006  NaN    1979-03-22                          NaN
# CA0110008  NaN    1979-03-22                          NaN
# CA0110009  NaN    1979-03-22                          NaN
# CA0110010  NaN    1979-03-22                          NaN
# CA0110011  NaN    1979-03-22                          NaN
# CA0110012  NaN    1976-01-01                          NaN
# CA0110016  NaN    1997-04-29                          NaN
# CA0110018  NaN    1976-01-01                          NaN
# CA0110019  NaN    1976-01-01                          NaN
# CA0110650  NaN    1994-06-27                          NaN
# CA0190001  NaN    1976-01-01                          NaN
# CA0190002  NaN    1976-01-01                          NaN
# CA0190003  NaN    1976-01-01                          NaN
# ...        ...           ...                          ...
# CA5800868  NaN    2015-08-04                          NaN
# CA5800874  NaN    2015-08-04                          NaN
# CA5800875  NaN    2015-08-04                          NaN
# CA5800876  NaN    2015-08-04                          NaN
# CA5800881  NaN    2015-08-04                          NaN
# CA5800884  NaN    2015-08-04                          NaN
# CA5800887  NaN    2015-08-04                          NaN
# CA5800888  NaN    2015-08-04                          NaN
# CA5800893  NaN    2015-08-04                          NaN
# CA5800897  NaN    2015-08-04                          NaN
# CA5800899  NaN    2015-08-04                          NaN
# CA5800901  NaN    2015-08-04                          NaN
# CA5800909  NaN    2015-08-04                          NaN
# CA5800913  NaN    2015-08-04                          NaN
# CA5800914  NaN    2015-08-04                          NaN
# CA5800919  NaN    2015-08-04                          NaN
# CA5800920  NaN    2015-08-04                          NaN
# CA5800923  NaN    2015-08-04                          NaN
# CA5800924  NaN    2016-07-28                          NaN
# CA5805001  NaN    2002-11-25                          NaN
# CA5810001  NaN    1979-03-22                          NaN
# CA5810002  NaN    1979-03-22                          NaN
# CA5810003  NaN    1979-03-22                          NaN
# CA5810004  NaN    1976-01-01                          NaN
# CA5810005  NaN    1976-01-01                          NaN
# CA5810006  NaN    1979-03-22                          NaN
# CA5810700  NaN    1981-01-05                          NaN
# CA5890001  NaN    1976-01-01                          NaN
# CA5890002  NaN    1976-01-01                          NaN
# CA5890003  NaN    2008-07-02                          NaN
#
#           coachella_vwd_id_no_11 coachella_vwd_id_no_8  \
# pws_id
# CA0103040                    NaN                   NaN
# CA0103041                    NaN                   NaN
# CA0105002                    NaN                   NaN
# CA0105003                    NaN                   NaN
# CA0105008                    NaN                   NaN
# CA0105009                    NaN                   NaN
# CA0105010                    NaN                   NaN
# CA0105012                    NaN                   NaN
# CA0105013                    NaN                   NaN
# CA0105016                    NaN                   NaN
# CA0105017                    NaN                   NaN
# CA0105018                    NaN                   NaN
# CA0105019                    NaN                   NaN
# CA0105020                    NaN                   NaN
# CA0110001                    NaN                   NaN
# CA0110003                    NaN                   NaN
# CA0110005                    NaN                   NaN
# CA0110006                    NaN                   NaN
# CA0110008                    NaN                   NaN
# CA0110009                    NaN                   NaN
# CA0110010                    NaN                   NaN
# CA0110011                    NaN                   NaN
# CA0110012                    NaN                   NaN
# CA0110016                    NaN                   NaN
# CA0110018                    NaN                   NaN
# CA0110019                    NaN                   NaN
# CA0110650                    NaN                   NaN
# CA0190001                    NaN                   NaN
# CA0190002                    NaN                   NaN
# CA0190003                    NaN                   NaN
# ...                          ...                   ...
# CA5800868                    NaN                   NaN
# CA5800874                    NaN                   NaN
# CA5800875                    NaN                   NaN
# CA5800876                    NaN                   NaN
# CA5800881                    NaN                   NaN
# CA5800884                    NaN                   NaN
# CA5800887                    NaN                   NaN
# CA5800888                    NaN                   NaN
# CA5800893                    NaN                   NaN
# CA5800897                    NaN                   NaN
# CA5800899                    NaN                   NaN
# CA5800901                    NaN                   NaN
# CA5800909                    NaN                   NaN
# CA5800913                    NaN                   NaN
# CA5800914                    NaN                   NaN
# CA5800919                    NaN                   NaN
# CA5800920                    NaN                   NaN
# CA5800923                    NaN                   NaN
# CA5800924                    NaN                   NaN
# CA5805001                    NaN                   NaN
# CA5810001                    NaN                   NaN
# CA5810002                    NaN                   NaN
# CA5810003                    NaN                   NaN
# CA5810004                    NaN                   NaN
# CA5810005                    NaN                   NaN
# CA5810006                    NaN                   NaN
# CA5810700                    NaN                   NaN
# CA5890001                    NaN                   NaN
# CA5890002                    NaN                   NaN
# CA5890003                    NaN                   NaN
#
#           don_pedro_rec_agblue_oaks don_pedro_rec_agflemmeadows federal_type  \
# pws_id
# CA0103040                       NaN                         NaN            C
# CA0103041                       NaN                         NaN            C
# CA0105002                       NaN                         NaN           NC
# CA0105003                       NaN                         NaN         NTNC
# CA0105008                       NaN                         NaN            C
# CA0105009                       NaN                         NaN         NTNC
# CA0105010                       NaN                         NaN           NC
# CA0105012                       NaN                         NaN           NC
# CA0105013                       NaN                         NaN           NC
# CA0105016                       NaN                         NaN           NC
# CA0105017                       NaN                         NaN           NC
# CA0105018                       NaN                         NaN           NC
# CA0105019                       NaN                         NaN           NC
# CA0105020                       NaN                         NaN         NTNC
# CA0110001                       NaN                         NaN            C
# CA0110003                       NaN                         NaN            C
# CA0110005                       NaN                         NaN            C
# CA0110006                       NaN                         NaN            C
# CA0110008                       NaN                         NaN            C
# CA0110009                       NaN                         NaN            C
# CA0110010                       NaN                         NaN            C
# CA0110011                       NaN                         NaN            C
# CA0110012                       NaN                         NaN            C
# CA0110016                       NaN                         NaN            C
# CA0110018                       NaN                         NaN            C
# CA0110019                       NaN                         NaN           NC
# CA0110650                       NaN                         NaN         NTNC
# CA0190001                       NaN                         NaN           NP
# CA0190002                       NaN                         NaN           NP
# CA0190003                       NaN                         NaN           NP
# ...                             ...                         ...          ...
# CA5800868                       NaN                         NaN           NC
# CA5800874                       NaN                         NaN           NC
# CA5800875                       NaN                         NaN           NC
# CA5800876                       NaN                         NaN           NC
# CA5800881                       NaN                         NaN           NC
# CA5800884                       NaN                         NaN           NC
# CA5800887                       NaN                         NaN           NC
# CA5800888                       NaN                         NaN           NC
# CA5800893                       NaN                         NaN           NC
# CA5800897                       NaN                         NaN           NC
# CA5800899                       NaN                         NaN         NTNC
# CA5800901                       NaN                         NaN           NC
# CA5800909                       NaN                         NaN         NTNC
# CA5800913                       NaN                         NaN         NTNC
# CA5800914                       NaN                         NaN           NC
# CA5800919                       NaN                         NaN         NTNC
# CA5800920                       NaN                         NaN           NC
# CA5800923                       NaN                         NaN           NC
# CA5800924                       NaN                         NaN            C
# CA5805001                       NaN                         NaN            C
# CA5810001                       NaN                         NaN            C
# CA5810002                       NaN                         NaN            C
# CA5810003                       NaN                         NaN            C
# CA5810004                       NaN                         NaN            C
# CA5810005                       NaN                         NaN            C
# CA5810006                       NaN                         NaN            C
# CA5810700                       NaN                         NaN            C
# CA5890001                       NaN                         NaN           NP
# CA5890002                       NaN                         NaN           NP
# CA5890003                       NaN                         NaN           NP
#
#           napa_county_schools_pope_valley nvusd_carneros_school  \
# pws_id
# CA0103040                             NaN                   NaN
# CA0103041                             NaN                   NaN
# CA0105002                             NaN                   NaN
# CA0105003                             NaN                   NaN
# CA0105008                             NaN                   NaN
# CA0105009                             NaN                   NaN
# CA0105010                             NaN                   NaN
# CA0105012                             NaN                   NaN
# CA0105013                             NaN                   NaN
# CA0105016                             NaN                   NaN
# CA0105017                             NaN                   NaN
# CA0105018                             NaN                   NaN
# CA0105019                             NaN                   NaN
# CA0105020                             NaN                   NaN
# CA0110001                             NaN                   NaN
# CA0110003                             NaN                   NaN
# CA0110005                             NaN                   NaN
# CA0110006                             NaN                   NaN
# CA0110008                             NaN                   NaN
# CA0110009                             NaN                   NaN
# CA0110010                             NaN                   NaN
# CA0110011                             NaN                   NaN
# CA0110012                             NaN                   NaN
# CA0110016                             NaN                   NaN
# CA0110018                             NaN                   NaN
# CA0110019                             NaN                   NaN
# CA0110650                             NaN                   NaN
# CA0190001                             NaN                   NaN
# CA0190002                             NaN                   NaN
# CA0190003                             NaN                   NaN
# ...                                   ...                   ...
# CA5800868                             NaN                   NaN
# CA5800874                             NaN                   NaN
# CA5800875                             NaN                   NaN
# CA5800876                             NaN                   NaN
# CA5800881                             NaN                   NaN
# CA5800884                             NaN                   NaN
# CA5800887                             NaN                   NaN
# CA5800888                             NaN                   NaN
# CA5800893                             NaN                   NaN
# CA5800897                             NaN                   NaN
# CA5800899                             NaN                   NaN
# CA5800901                             NaN                   NaN
# CA5800909                             NaN                   NaN
# CA5800913                             NaN                   NaN
# CA5800914                             NaN                   NaN
# CA5800919                             NaN                   NaN
# CA5800920                             NaN                   NaN
# CA5800923                             NaN                   NaN
# CA5800924                             NaN                   NaN
# CA5805001                             NaN                   NaN
# CA5810001                             NaN                   NaN
# CA5810002                             NaN                   NaN
# CA5810003                             NaN                   NaN
# CA5810004                             NaN                   NaN
# CA5810005                             NaN                   NaN
# CA5810006                             NaN                   NaN
# CA5810700                             NaN                   NaN
# CA5890001                             NaN                   NaN
# CA5890002                             NaN                   NaN
# CA5890003                             NaN                   NaN
#
#           nvusd_mt_george_school primary_source principal_county_served  \
# pws_id
# CA0103040                    NaN             GW                 ALAMEDA
# CA0103041                    NaN            SWP                 ALAMEDA
# CA0105002                    NaN             GW                 ALAMEDA
# CA0105003                    NaN             GW                 ALAMEDA
# CA0105008                    NaN            GWP                 ALAMEDA
# CA0105009                    NaN            GWP                 ALAMEDA
# CA0105010                    NaN             SW                 ALAMEDA
# CA0105012                    NaN             GW                 ALAMEDA
# CA0105013                    NaN             GW                 ALAMEDA
# CA0105016                    NaN             GW                 ALAMEDA
# CA0105017                    NaN             GW                 ALAMEDA
# CA0105018                    NaN             GW                 ALAMEDA
# CA0105019                    NaN             GW                 ALAMEDA
# CA0105020                    NaN             GW                 ALAMEDA
# CA0110001                    NaN             SW                 ALAMEDA
# CA0110003                    NaN            SWP                 ALAMEDA
# CA0110005                    NaN             SW                 ALAMEDA
# CA0110006                    NaN            SWP                 ALAMEDA
# CA0110008                    NaN            SWP                 ALAMEDA
# CA0110009                    NaN            SWP                 ALAMEDA
# CA0110010                    NaN             SW                 ALAMEDA
# CA0110011                    NaN            SWP                 ALAMEDA
# CA0110012                    NaN            SWP                 ALAMEDA
# CA0110016                    NaN            SWP                 ALAMEDA
# CA0110018                    NaN             GW                 ALAMEDA
# CA0110019                    NaN             GW                 ALAMEDA
# CA0110650                    NaN             SW                 ALAMEDA
# CA0190001                    NaN                                ALAMEDA
# CA0190002                    NaN                                ALAMEDA
# CA0190003                    NaN                                ALAMEDA
# ...                          ...            ...                     ...
# CA5800868                    NaN             GW                    YUBA
# CA5800874                    NaN             GW                    YUBA
# CA5800875                    NaN             GW                    YUBA
# CA5800876                    NaN             GW                    YUBA
# CA5800881                    NaN             GW                    YUBA
# CA5800884                    NaN             GW                    YUBA
# CA5800887                    NaN             GW                    YUBA
# CA5800888                    NaN             GW                    YUBA
# CA5800893                    NaN             GW                    YUBA
# CA5800897                    NaN             GW                    YUBA
# CA5800899                    NaN             GW                    YUBA
# CA5800901                    NaN             GW                    YUBA
# CA5800909                    NaN             GW                    YUBA
# CA5800913                    NaN             GW                    YUBA
# CA5800914                    NaN             GW                    YUBA
# CA5800919                    NaN             GW                    YUBA
# CA5800920                    NaN             GW                    YUBA
# CA5800923                    NaN             GW                    YUBA
# CA5800924                    NaN             SW                    YUBA
# CA5805001                    NaN             GW                    YUBA
# CA5810001                    NaN             GW                    YUBA
# CA5810002                    NaN             GW                    YUBA
# CA5810003                    NaN             GW                    YUBA
# CA5810004                    NaN             GW                    YUBA
# CA5810005                    NaN             SW                    YUBA
# CA5810006                    NaN             SW                    YUBA
# CA5810700                    NaN             GW                    YUBA
# CA5890001                    NaN                                   YUBA
# CA5890002                    NaN                                   YUBA
# CA5890003                    NaN                                   YUBA
#
#           shoreline_school_dist_bus_garage state_type status  \
# pws_id
# CA0103040                              NaN          C      A
# CA0103041                              NaN          C      A
# CA0105002                              NaN         NC      A
# CA0105003                              NaN       NTNC      A
# CA0105008                              NaN          C      A
# CA0105009                              NaN       NTNC      A
# CA0105010                              NaN         NC      A
# CA0105012                              NaN         NC      A
# CA0105013                              NaN         NC      A
# CA0105016                              NaN         NC      A
# CA0105017                              NaN         NC      A
# CA0105018                              NaN         NC      A
# CA0105019                              NaN         NC      A
# CA0105020                              NaN       NTNC      A
# CA0110001                              NaN          C      A
# CA0110003                              NaN          C      A
# CA0110005                              NaN          C      A
# CA0110006                              NaN          C      A
# CA0110008                              NaN          C      A
# CA0110009                              NaN          C      A
# CA0110010                              NaN          C      A
# CA0110011                              NaN          C      A
# CA0110012                              NaN          C      A
# CA0110016                              NaN          C      A
# CA0110018                              NaN          C      A
# CA0110019                              NaN         NC      A
# CA0110650                              NaN       NTNC      A
# CA0190001                              NaN         RW      A
# CA0190002                              NaN         RW      A
# CA0190003                              NaN         RW      A
# ...                                    ...        ...    ...
# CA5800868                              NaN         NC      A
# CA5800874                              NaN         NC      A
# CA5800875                              NaN         NC      A
# CA5800876                              NaN         NC      A
# CA5800881                              NaN         NC      A
# CA5800884                              NaN         NC      A
# CA5800887                              NaN         NC      A
# CA5800888                              NaN         NC      A
# CA5800893                              NaN         NC      A
# CA5800897                              NaN         NC      A
# CA5800899                              NaN       NTNC      A
# CA5800901                              NaN         NC      A
# CA5800909                              NaN       NTNC      A
# CA5800913                              NaN       NTNC      A
# CA5800914                              NaN         NC      A
# CA5800919                              NaN       NTNC      A
# CA5800920                              NaN         NC      A
# CA5800923                              NaN         NC      A
# CA5800924                              NaN          C      A
# CA5805001                              NaN          C      A
# CA5810001                              NaN          C      A
# CA5810002                              NaN          C      A
# CA5810003                              NaN          C      A
# CA5810004                              NaN          C      A
# CA5810005                              NaN          C      A
# CA5810006                              NaN          C      A
# CA5810700                              NaN          C      A
# CA5890001                              NaN         RW      A
# CA5890002                              NaN         RW      A
# CA5890003                              NaN         RW      A
#
#                                   water_system_name water_system_no
# pws_id
# CA0103040        NORRIS CANYON PROPERTY OWNERS ASSN       CA0103040
# CA0103041            TRAILER HAVEN MOBILE HOME PARK       CA0103041
# CA0105002                         RIVERS END MARINA       CA0105002
# CA0105003                         CEMEX/ELIOT PLANT       CA0105003
# CA0105008          CASTLEWOOD DOMESTIC WATER SYSTEM       CA0105008
# CA0105009                     MOUNTAIN HOUSE SCHOOL       CA0105009
# CA0105010           EBRPD - DEL VALLE REGIONAL PARK       CA0105010
# CA0105012         EBRPD - SUNOL REGIONAL WILDERNESS       CA0105012
# CA0105013      EBRPD - REDWOOD SPRING REGIONAL PARK       CA0105013
# CA0105016                        MOUNTAIN HOUSE BAR       CA0105016
# CA0105017                RANCHO LOS MOCHOS-BSA CAMP       CA0105017
# CA0105018                  PURPLE ORCHID RESORT SPA       CA0105018
# CA0105019                          SUNOL SUPER STOP       CA0105019
# CA0105020                ALAMEDA COUNTY FAIRGROUNDS       CA0105020
# CA0110001             ALAMEDA COUNTY WATER DISTRICT       CA0110001
# CA0110003      CALIFORNIA WATER SERVICE - LIVERMORE       CA0110003
# CA0110005                              EAST BAY MUD       CA0110005
# CA0110006                           CITY OF HAYWARD       CA0110006
# CA0110008                        CITY OF PLEASANTON       CA0110008
# CA0110009        DUBLIN SAN RAMON SERVICES DISTRICT       CA0110009
# CA0110010                       ZONE 7 WATER AGENCY       CA0110010
# CA0110011                         CITY OF LIVERMORE       CA0110011
# CA0110012                       TOWN OF SUNOL-SFPUC       CA0110012
# CA0110016                             ALAMEDA POINT       CA0110016
# CA0110018                    SFPUC-PLEASANTON WELLS       CA0110018
# CA0110019                        GOLDEN GATE CHURCH       CA0110019
# CA0110650     USBR-SLDMWA - CVP JONES PUMPING PLANT       CA0110650
# CA0190001        DUBLIN SAN RAMON SERVICES DISTRICT       CA0190001
# CA0190002                         CITY OF LIVERMORE       CA0190002
# CA0190003                           EBMUD ENAQUA UV       CA0190003
# ...                                             ...             ...
# CA5800868                      OREGON HOUSE GROCERY       CA5800868
# CA5800874                           LOMA RICA STORE       CA5800874
# CA5800875                          WILLOW GLEN CAFE       CA5800875
# CA5800876                      GOLD EAGLE MARKET #2       CA5800876
# CA5800881                         BROWNS VALLEY BAR       CA5800881
# CA5800884                        YOUNGLIFE WOODLEAF       CA5800884
# CA5800887                            PIZZA ROUND UP       CA5800887
# CA5800888                          SEVEN MILE HOUSE       CA5800888
# CA5800893  YUBA COUNTY LEADERSHIP & ADVENTURE CENTE       CA5800893
# CA5800897                            COUNTRY MARKET       CA5800897
# CA5800899                 NORTH YUBA RANGER STATION       CA5800899
# CA5800901                       FOOTHILL LIONS CLUB       CA5800901
# CA5800909                   SHOEI FOODS (USA), INC.       CA5800909
# CA5800913                       US PIPE FABRICATION       CA5800913
# CA5800914                   MARYSVILLE RACEWAY PARK       CA5800914
# CA5800919                                      PG&E       CA5800919
# CA5800920                   WILLOW CREEK CAMPGROUND       CA5800920
# CA5800923                    MARYSVILLE FLEA MARKET       CA5800923
# CA5800924          CAMPTONVILLE COMMUNITY SERV DIST       CA5800924
# CA5805001                               PLUMAS LAKE       CA5805001
# CA5810001          CAL-WATER SERVICE CO.-MARYSVILLE       CA5810001
# CA5810002               LINDA COUNTY WATER DISTRICT       CA5810002
# CA5810003                    OLIVEHURST PUBLIC U.D.       CA5810003
# CA5810004                         CITY OF WHEATLAND       CA5810004
# CA5810005                    NEVADA ID - SMARTVILLE       CA5810005
# CA5810006                 NORTH YUBA WATER DISTRICT       CA5810006
# CA5810700                      BEALE AIR FORCE BASE       CA5810700
# CA5890001            CITY OF MARYSVILLE WW DISTRICT       CA5890001
# CA5890002                     YUBA COUNTY MOTORPLEX       CA5890002
# CA5890003                              BEALE AFB WW       CA5890003
#
# [8327 rows x 18 columns]

# %%
(d.get_table_water_sources()
)
# Out:
#                                                         name status type_code
# pws_id    entry_id
# CA0103040 0                                   CISTERN SPRING      A        SP
#           1                                     LOWER SPRING      A        SP
#           2                                     UPPER SPRING      A        SP
# CA0103041 0                                 EBMUD CONNECTION      A        CC
#           1                                          WELL 01      A        WL
# CA0105002 0                                          WELL 01      A        WL
# CA0105003 0                                           WELL 2      A        WL
#           1                                       ELIOT WELL      I        WL
# CA0105008 0                           SFPUC PLEASANTON WELLS      A        CC
#           1                               WELL 03 - INACTIVE      I        WL
# CA0105009 0                                     HAULED WATER      A        NP
#           1                                          WELL 01      I        WL
# CA0105010 0                                   LAKE DEL VALLE      A        IN
# CA0105012 0                           WELL 01 (HEADQUARTERS)      A        WL
#           1                            WELL 02 (HIGH VALLEY)      A        WL
# CA0105013 0                                        SPRING 02      A        SP
# CA0105016 0                                        MAIN WELL      A        WL
# CA0105017 0                                        SPRING 01      A        SP
# CA0105018 0                                         POI WELL      A        WL
# CA0105019 0                                     WATER WELL-1      A        WL
# CA0105020 0                                   AUXILIARY WELL      A        WL
#           1                                        MAIN WELL      A        WL
# CA0110001 0                      SF TURNOUT - CENTRAL/CHERRY      A        CC
#           1         SF TURNOUT AT PT BLENDING FACILITY (SF1)      A        CC
#           2                               SOUTH BAY AQUEDUCT      A        IN
#           3                         LAKE DEL VALLE RESERVOIR      A        RS
#           4                                  BELLFLOWER WELL      A        WL
#           5                                    CEDAR WELL 01      A        WL
#           6                                    CEDAR WELL 02      A        WL
#           7                                   DARVON WELL 01      A        WL
# ...                                                      ...    ...       ...
# CA5810003 3                                WELL 14 - STANDBY      A        WL
#           4                                          WELL 28      A        WL
#           5                                          WELL 29      A        WL
#           6                                          WELL 30      A        WL
#           7                         WELL 05 - DESTROYED XCLD      I        WL
#           8                         WELL 06 - DESTROYED XCLD      I        WL
#           9                         WELL 09A - INACTIVE XCLD      I        WL
#           10                       WELL 15A - DESTROYED XCLD      I        WL
#           11                        WELL 27 - DESTROYED XCLD      I        WL
# CA5810004 0                          NEW WELL 03 - CORP YARD      A        WL
#           1                                      NEW WELL 04      A        WL
#           2                                          WELL 05      A        WL
#           3                                          WELL 06      A        WL
#           4                         WELL 07 - FORECAST HOMES      A        WL
#           5                                          WELL 08      A        WL
#           6                 WELL 03 - DESTROYED 2/11/02 XCLD      I        WL
#           7                         WELL 04 - DESTROYED XCLD      I        WL
#           8         WELL 09 (HERITAGE OAKS NORTH WELL)-INACT      I        WL
#           9          WELL 10 (HERITAGE OAKS WEST) - INACTIVE      I        WL
# CA5810005 0                 NID - SMARTVILLE RAW CHINA DITCH      A        IN
# CA5810006 0                     FORBESTOWN DITCH INTAKE DEAD      A        IN
# CA5810700 0                                          WELL 01      A        WL
#           1                                          WELL 02      A        WL
#           2                                          WELL 04      A        WL
#           3                                          WELL 05      A        WL
#           4                                          WELL 06      A        WL
#           5                                          WELL 08      A        WL
#           6                                          WELL 09      A        WL
#           7                                          WELL 03      I        WL
#           8                                          WELL 07      I        WL
#
# [26673 rows x 3 columns]

# %%
(d.get_table_service_connections()
 .sort_values('count', ascending=False)
)
# Out:
#                      count  meter_size_measure meter_type type
# pws_id    entry_id
# CA1910067 3         609694                   0         ME   RS
# CA0110005 0         387846                   0         ME   CB
# CA3710020 3         225109                   0         ME   RS
# CA4310011 2         204733                   0         ME   RS
# CA3810011 0         170509                   0         ME   CB
# CA3410020 0         157312                   0         UN   CB
# CA3310009 0         146850                   0         ME   CB
# CA1010007 0         132981                   0         ME   CB
# CA3310001 0         104188                   0         ME   CB
# CA3010092 4          98901                   0         ME   RS
# CA0110001 0          84730                   0         UN   CB
# CA1910065 3          80271                   0         ME   RS
# CA1510055 0          70062                   0         UN   CB
# CA1510003 0          69810                   0         UN   CB
# CA5010010 0          69306                   0         UN   CB
# CA3310031 0          65447                   0         ME   CB
# CA3010001 0          62615                   0         UN   CB
# CA1910067 1          61362                   0         ME   CM
# CA2110002 0          60585                   0         UN   CB
# CA0710003 0          60334                   0         ME   CB
# CA4910009 0          53599                   0         UN   CB
# CA3010053 0          53020                   0         UN   CB
# CA3710034 0          48747                   0         ME   CB
# CA3910012 0          48674                   0         UN   CB
# CA3010073 3          47278                   0         ME   RS
# CA1910070 2          46922                   0         ME   RS
# CA3710010 3          46763                   0         ME   RS
# CA1910155 3          46625                   0         ME   RS
# CA3410001 0          46318                   0         UN   CB
# CA1510031 0          45038                   0         UN   CB
# ...                    ...                 ...        ...  ...
# CA1502260 1              0                   0         UN   CB
# CA1502229 0              0                   0         UM   AG
#           1              0                   0         UN   CB
#           2              0                   0         UM   CM
# CA1502231 0              0                   0         UM   CB
#           1              0                   0         UN   CB
#           3              0                   0         UM   IN
# CA1502232 0              0                   0         UN   CB
# CA1502247 0              0                   0         UN   CB
#           1              0                   0         ME   CM
# CA1502249 0              0                   0         ME   CM
# CA2790013 0              0                   0         MU   RS
# CA1502249 2              0                   0         ME   IN
#           3              0                   0         ME   RS
# CA1502260 3              0                   0         UM   CM
# CA1502325 0              0                   0         UM   CB
# CA1502260 4              0                   0         ME   IN
# CA1502273 0              0                   0         UN   CB
#           2              0                   0         UM   IN
# CA1502277 0              0                   0         UN   CB
#           2              0                   0         UM   IN
# CA1502315 0              0                   0         UN   CB
#           2              0                   0         UM   IN
#           3              0                   0         UM   RS
# CA1502317 0              0                   0         UM   CB
#           1              0                   0         UN   CB
# CA1502319 0              0                   0         ME   CB
#           1              0                   0         UN   CB
# CA1502323 1              0                   0         UN   CB
# CA1510301 1              0                   0         UM   CB
#
# [9592 rows x 4 columns]

# %%
d.get_table_service_areas()
# Out:
#                    code                      name
# pws_id    entry_id
# CA0103040 0           R          RESIDENTIAL AREA
# CA0103041 0           R          MOBILE HOME PARK
# CA0105002 0           T           RECREATION AREA
# CA0105003 0          NT   INDUSTRIAL/AGRICULTURAL
# CA0105008 0           R          RESIDENTIAL AREA
# CA0105009 0          NT                    SCHOOL
# CA0105010 0           T           RECREATION AREA
# CA0105012 0           T           RECREATION AREA
# CA0105013 0           T           RECREATION AREA
# CA0105016 0           T                RESTAURANT
# CA0105017 0           T               SUMMER CAMP
# CA0105018 0           T               HOTEL/MOTEL
# CA0105019 0           T           SERVICE STATION
# CA0105020 0           T           RECREATION AREA
# CA0110001 0           R          RESIDENTIAL AREA
# CA0110003 0           R          RESIDENTIAL AREA
# CA0110005 0           R              MUNICIPALITY
#           1           O  WHOLESALER (SELLS WATER)
# CA0110006 0           R          RESIDENTIAL AREA
# CA0110008 0           R          RESIDENTIAL AREA
# CA0110009 0           R          RESIDENTIAL AREA
# CA0110010 0           O  WHOLESALER (SELLS WATER)
# CA0110011 0           R          RESIDENTIAL AREA
# CA0110012 0           R          RESIDENTIAL AREA
# CA0110016 0           O                OTHER AREA
# CA0110018 0           O  WHOLESALER (SELLS WATER)
# CA0110019 0           T      OTHER TRANSIENT AREA
# CA0110650 0          NT   INDUSTRIAL/AGRICULTURAL
# CA0190001 0           O            RECYCLED WATER
# CA0190002 0           O            RECYCLED WATER
# ...                 ...                       ...
# CA5800884 0           T               SUMMER CAMP
# CA5800887 0           T                RESTAURANT
# CA5800888 0           T                RESTAURANT
# CA5800893 0           T               SUMMER CAMP
# CA5800897 0           T      OTHER TRANSIENT AREA
# CA5800899 0           O                OTHER AREA
#           1           T      SECONDARY RESIDENCES
# CA5800901 0           T                RESTAURANT
# CA5800909 0          NT   INDUSTRIAL/AGRICULTURAL
# CA5800913 0          NT   INDUSTRIAL/AGRICULTURAL
# CA5800914 0           T      OTHER TRANSIENT AREA
#           1           T           RECREATION AREA
# CA5800919 0          NT   INDUSTRIAL/AGRICULTURAL
# CA5800920 0           T           RECREATION AREA
#           1           T               SUMMER CAMP
# CA5800923 0           T      OTHER TRANSIENT AREA
#           1           T           RECREATION AREA
# CA5800924 0           R          RESIDENTIAL AREA
#           1           T      SECONDARY RESIDENCES
# CA5805001 0           R          RESIDENTIAL AREA
# CA5810001 0           R          RESIDENTIAL AREA
# CA5810002 0           R          RESIDENTIAL AREA
# CA5810003 0           R          RESIDENTIAL AREA
# CA5810004 0           O                OTHER AREA
# CA5810005 0           R          RESIDENTIAL AREA
# CA5810006 0           R          RESIDENTIAL AREA
# CA5810700 0          NT               INSTITUTION
# CA5890001 0           O            RECYCLED WATER
# CA5890002 0           O            RECYCLED WATER
# CA5890003 0           O            RECYCLED WATER
#
# [8358 rows x 2 columns]

# %%
(d.get_table_water_purchases()
 .reset_index()
 .groupby('seller_water_system_no')
 .agg({'water_system_name': 'first', 'pws_id': 'count'})
 .rename(columns={'pws_id': 'buyer_count'})
 .sort_values('buyer_count', ascending=False)
)
# Out:
#                                                water_system_name  buyer_count
# seller_water_system_no
# CA1910087                   METROPOLITAN WATER DIST. OF SO. CAL.          345
# CA3710042                       SAN DIEGO COUNTY WATER AUTHORITY           77
# CA3810001                    SAN FRANCISCO REGIONAL WATER SYSTEM           62
# CA4310027                      SANTA CLARA VALLEY WATER DISTRICT           31
# CA1910045                 ANTELOPE VALLEY-EAST KERN WATER AGENCY           29
# CA3710020                                     SAN DIEGO, CITY OF           27
# CA1910199                      CALIFORNIA DOMESTIC WATER COMPANY           25
# CA3310009                                   EASTERN MUNICIPAL WD           22
# CA5610050                         CALLEGUAS MUNICIPAL WATER DIST           21
# CA4310011                                         SAN JOSE WATER           20
# CA1310014                           IMPERIAL IRRIGATION DISTRICT           19
# CA3010071                     JOINT REGIONAL WATER SUPPLY SYSTEM           19
# CA1910048               SANTA CLARITA VALLEY W.A.-IMPORTED DIVIS           19
# CA4210030                          CENTRAL COAST WATER AUTHORITY           18
# CA3710034                                    OTAY WATER DISTRICT           17
# CA1910041                                      THREE VALLEYS MWD           17
# CA3010093                             EAST ORANGE COUNTY WD - WZ           16
# CA3710010                                   HELIX WATER DISTRICT           14
# CA4910020                             SONOMA COUNTY WATER AGENCY           14
# CA5610046                                   UNITED WTR CONS DIST           12
# CA3610114                                                  CLAWA           11
# CA5610024                           CASITAS MUNICIPAL WATER DIST           10
# CA3710025                                   SWEETWATER AUTHORITY           10
# CA3010003                                     CITY OF BUENA PARK            9
# CA3710037                                          PADRE DAM MWD            9
# CA1910032                         FOOTHILL MUNICIPAL WATER DIST.            9
# CA0710003                            CONTRA COSTA WATER DISTRICT            9
# CA3310021                                    JURUPA COMMUNITY SD            9
# CA1510053                ANTELOPE VALLEY E KERN WTR AGY-ROSAMOND            8
# CA0910001                                    EL DORADO ID - MAIN            8
# ...                                                          ...          ...
# CA1910001                                       CITY OF ALHAMBRA            1
# CA1900912                               GORMAN ELEMENTARY SCHOOL            1
# CA3610086                    WEST END CONSOLIDATED WATER COMPANY            1
# CA3610110                                     ARROWBEAR PARK CWD            1
# CA1900849                            LLANO DEL RIO WATER COMPANY            1
# CA3610120                                 PHELAN PINON HILLS CSD            1
# CA3610850                         CALIFORNIA INSTITUTION FOR MEN            1
# CA1900767                 GOLDEN VALLEY MUNICIPAL WATER DISTRICT            1
# CA1900587                                       USFS CLEAR CREEK            1
# CA3010036                                   CITY OF SAN CLEMENTE            1
# CA1710006                          KONOCTI COUNTY WATER DISTRICT            1
# CA1910005               LOS ANGELES CO WW DIST 40 REG 38 LAKE LA            1
# CA1910007                                  AZUSA LIGHT AND WATER            1
# CA3610044                          DWP - BIG BEAR LAKE/MOONRIDGE            1
# CA1910052                   CAL/AM WATER COMPANY - BALDWIN HILLS            1
# CA1910124                             PASADENA-CITY, WATER DEPT.            1
# CA1910102                                   PALMDALE WATER DIST.            1
# CA1910070                LOS ANGELES CO WW DIST 4 & 34-LANCASTER            1
# CA3510001                                     HOLLISTER, CITY OF            1
# CA3510002                             SAN JUAN BAUTISTA, CITY OF            1
# CA3610001                                      ADELANTO, CITY OF            1
# CA1910034                             DOWNEY - CITY, WATER DEPT.            1
# CA3610043                        GOLDEN STATE WATER CO - BARSTOW            1
# CA3610009                     BIGHORN - DESERT VIEW WATER AGENCY            1
# CA3610018                        CUCAMONGA VALLEY WATER DISTRICT            1
# CA1910025                 LOS ANGELES CWWD 40 REG. 39-ROCK CREEK            1
# CA3610036                                   CHINO HILLS, CITY OF            1
# CA1910019                           CERRITOS - CITY, WATER DEPT.            1
# CA1910017                SANTA CLARITA VALLEY W.A.-SANTA CLARITA            1
# CA5710012                      WOODLAND-DAVIS CLEAN WATER AGENCY            1
#
# [265 rows x 2 columns]

# %%
from config import PATH_DATA

PATH_DATA
# Out:
# PosixPath('data-out')

# %%
d.to_csv(PATH_DATA)

# %%
d.to_json(PATH_DATA)
