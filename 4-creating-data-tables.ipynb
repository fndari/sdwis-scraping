# %%
import pandas as pd

import json
from pathlib import Path

# %%
from config import PATH_PARSED_RECORDS
PATH_PARSED_RECORDS
# Out:
# PosixPath('data/intermediate-results/parsed-records.json')

# %% [markdown]
# # Creating Data Tables
#
# The last step is to process the parsed data to flat data tables.
#
# Some utility functions to regularize field/column names and enhance data quality:

# %%
import re

def to_snakecase(s):
    import re
    
    # convert one or more spaces to underscore
    s = re.sub('\s+', '_', s.strip())
    # strip all other non-alphanumeric chars
    return (re.sub('\W', '', s)
            .lower()
           )

def normalize_column_names(df):
    return df.rename(columns=to_snakecase)

def drop_columns_robust(df, cols):
    to_drop = df.columns & set(cols)
    
    return df.drop(columns=to_drop)

def drop_columns_with_nulls(df, max_null_fraction=0):
    null_fraction = df.pipe(lambda d: 1 - d.count() / len(d))
    cols_to_keep = null_fraction[lambda col: col <= max_null_fraction].index
    return df[cols_to_keep]

def to_category(df, cols):
    return df.astype({col: 'category' for col in cols})

# %% [markdown]
# We can also creae a container class to interact with the dataset as parsed records:

# %%
class WSDDataset:
    
    @classmethod
    def from_records(cls, path=None):
        if path:
            records = json.loads(Path(path).read_text())
        return cls(records)
    
    def __init__(self, records=None):
        self.records = records or []
        
    def __repr__(self):
        return f'{type(self).__name__}(len={len(self)})'
        
    def __iter__(self):
        return iter(self.records)
    
    def __len__(self):
        return len(self.records)
    
    def _get_table_from_record_dict(self, field_name):
        return pd.DataFrame([dict(pws_id=r['pws_id'], **r[field_name]) for r in self])

    def _get_table_from_record_list(self, field_name, as_index=None):
        # TODO add option to set the `entry_id` name to a custom value
        df = (pd.DataFrame([dict(pws_id=r['pws_id'], entry_id=entry_id, **field_data)
                         for r in self
                         for entry_id, field_data in enumerate(r[field_name])])
          )

        if as_index:
            df = df.set_index(as_index)
        return df
    
    def get_table_details(self):

        return (self._get_table_from_record_dict('water_system_details')
                .set_index('pws_id')
                # there are some spurious columns, defined only for a minority of the PWSs
                # we retain only columns containing data for a relevant fraction of the dataset
                .pipe(drop_columns_with_nulls, max_null_fraction=0.1)
                .pipe(normalize_column_names)
                .pipe(to_category, ['federal_type', 'primary_source', 'state_type', 'status'])
                .assign(activity_date=lambda d: pd.to_datetime(d['activity_date']))
               )
    
    def get_table_service_connections(self):
        return (self._get_table_from_record_list('service_connections', as_index=['pws_id', 'entry_id'])
                .pipe(normalize_column_names)
                .pipe(to_category, ['meter_type', 'type'])
               )
    
    def get_table_service_areas(self):
        return (self._get_table_from_record_list('service_areas', as_index=['pws_id', 'entry_id'])
                .pipe(normalize_column_names)
                .pipe(to_category, ['code', 'name'])
               )
    
    def get_table_water_sources(self):
        return (self._get_table_from_record_list('water_sources', as_index=['pws_id', 'entry_id'])
                .pipe(normalize_column_names)
                .pipe(to_category, ['status', 'type_code'])
               )
    
    def get_table_water_purchases(self):
        return (self._get_table_from_record_list('water_purchases', as_index=['pws_id', 'entry_id'])
                .pipe(normalize_column_names)
                .pipe(to_category, ['buyer_facility_type', 'seller_facility_type'])
               )
    
    def to_csv(self, path):

        names_functions = [
            ('details', self.get_table_details),
            ('service-connections', self.get_table_service_connections),
            ('service-areas', self.get_table_service_areas),
            ('water-sources', self.get_table_water_sources),
            ('water-purchases', self.get_table_water_purchases),
        ]
        
        for name, f in names_functions:
            path_file = (path / name).with_suffix('.csv')
            df = f()
            df.to_csv(path_file)
            
    def to_json(self, path):
        import json

        with (path / 'records.json').open('w') as f:
            json.dump(self.records, f, indent=4)

# %%
d = WSDDataset.from_records(path=PATH_PARSED_RECORDS)
d
# Out:
# WSDDataset(len=8327)

# %%
def get_category_fraction(s):
    df = pd.DataFrame({'counts': s.value_counts()})
    return df.assign(fraction=lambda d: (d.counts / d.counts.sum()),
                     cum_fraction=lambda d: d.fraction.cumsum(),
                     )

def get_info_categories(df):
    for col in df.select_dtypes(include='category'):
        s = df[col]
        print(f'{col} ({s.cat.categories}')
        display(s.pipe(get_category_fraction))

# %%
(d.get_table_details()
#  .pipe(get_info_categories)
)
# Out:
#           activity_date federal_type primary_source principal_county_served  \
# pws_id
# CA3010071    1976-01-01            C            SWP                  ORANGE
# CA4800564    1979-03-22            C             GW                  SOLANO
# CA1503243    2016-09-20         NTNC             GW                    KERN
# CA3901464    2016-08-08           NC             GW             SAN JOAQUIN
# CA1900868    2013-06-08            C             GW             LOS ANGELES
# CA2490001    1976-01-01           NP                                 MERCED
# CA1000459    1993-02-09           NC             GW                  FRESNO
# CA3901368    2016-08-08         NTNC             GW             SAN JOAQUIN
# CA2900532    2016-08-08         NTNC             GW                  NEVADA
# CA4200862    2016-07-26            C             GW           SANTA BARBARA
# CA1910028    1976-01-01            C            SWP             LOS ANGELES
# CA1910225    1976-01-01            C             SW             LOS ANGELES
# CA4900707    1979-03-22         NTNC             GW                  SONOMA
# CA1504004    2016-10-03         NTNC             GW                    KERN
# CA5690004    1996-01-03           NP                                VENTURA
# CA0710800    1992-04-15         NTNC             SW            CONTRA COSTA
# CA5400538    2014-04-28         NTNC             GW                  TULARE
# CA2701263    2016-08-01            C             SW                MONTEREY
# CA5403031    2014-04-28         NTNC             GW                  TULARE
# CA1502465    1984-04-26            C             GW                    KERN
# CA2702412    2016-08-01         NTNC             GW                MONTEREY
# CA5000166    2016-07-21           NC             GW              STANISLAUS
# CA2300596    1992-12-04            C             GW               MENDOCINO
# CA3400331    2016-08-08            C             GW              SACRAMENTO
# CA4990013    1976-01-01           NP                                 SONOMA
# CA3303095    2013-06-08           NP                              RIVERSIDE
# CA4010003    1979-03-22            C            SWP         SAN LUIS OBISPO
# CA4500343    2017-07-24           NC             GW                  SHASTA
# CA4300808    1981-11-30         NTNC            SWP             SANTA CLARA
# CA3601158    2016-08-08           NC             GW          SAN BERNARDINO
# ...                 ...          ...            ...                     ...
# CA3303072    2016-07-27         NTNC             GW               RIVERSIDE
# CA4400758    2015-01-29         NTNC             GW              SANTA CRUZ
# CA2701280    2016-08-01            C             SW                MONTEREY
# CA1500481    1979-03-22            C             GW                    KERN
# CA2790005    1999-04-06           NP                               MONTEREY
# CA4901232    1976-01-01         NTNC             GW                  SONOMA
# CA5601405    1986-03-28         NTNC             GW                 VENTURA
# CA4400660    2015-01-29            C             GW              SANTA CRUZ
# CA4200877    2016-07-26           NC             GW           SANTA BARBARA
# CA3601064    2016-08-08         NTNC             GW          SAN BERNARDINO
# CA5800914    2015-08-04           NC             GW                    YUBA
# CA2000535    2015-11-06           NC             GW                  MADERA
# CA4500098    2015-04-30            C             GW                  SHASTA
# CA2000621    2015-11-06           NC             GW                  MADERA
# CA1000507    1996-07-23         NTNC             GW                  FRESNO
# CA1500216    1992-12-03            C             GW                    KERN
# CA5000101    2016-07-21         NTNC             GW              STANISLAUS
# CA5402030    2016-01-06           NC             GW                  TULARE
# CA0710300    1979-03-22           NC             GW            CONTRA COSTA
# CA5810004    1976-01-01            C             GW                    YUBA
# CA0707503    2016-05-10           NC             GW            CONTRA COSTA
# CA2702253    1996-10-04           NP             GW                MONTEREY
# CA1900035    2016-08-08         NTNC             GW             LOS ANGELES
# CA3990011    2016-08-24           NP                            SAN JOAQUIN
# CA1000111    1979-03-22         NTNC             GW                  FRESNO
# CA2000627    2015-11-06           NC             GW                  MADERA
# CA1910023    1979-03-22            C             GW             LOS ANGELES
# CA4210016    1979-03-22            C             GW           SANTA BARBARA
# CA4901082    1987-10-20           NC             GW                  SONOMA
# CA3601157    2016-08-08           NC             GW          SAN BERNARDINO
#
#           state_type status                         water_system_name  \
# pws_id
# CA3010071          C      A        JOINT REGIONAL WATER SUPPLY SYSTEM
# CA4800564          C      A                HIDDEN ACRES TRAILER VILLA
# CA1503243       NTNC      A                      HONDA PROVING CENTER
# CA3901464         NC      A        DESHMESH DARBAR LODI/STK WATER SYS
# CA1900868          C      A                   RIVERS END TRAILER PARK
# CA2490001         RW      A                           CITY OF GUSTINE
# CA1000459         NC      A                 ROAD RUNNER FOOD AND FUEL
# CA3901368       NTNC      A              OM SCOTT & SONS/HYPONEX CORP
# CA2900532       NTNC      A               PENN VALLEY SHOPPING CENTER
# CA4200862          C      A                         MESA HILLS MUTUAL
# CA1910028          C      A                      CRESCENTA VALLEY CWD
# CA1910225          C      A                          LAS VIRGENES MWD
# CA4900707       NTNC      A  TWIN HILLS SCHOOL DIST-TWIN HILLS SCHOOL
# CA1504004       NTNC      A             BLOSSOM VALLEY ORGANICS SOUTH
# CA5690004         RW      A            TRIUNFO-TOLAND SANITATION DIST
# CA0710800       NTNC      A       DWR DELTA FIELD DIVISION - BANKS PP
# CA5400538       NTNC      A           ACCELERATED CHARTER HIGH SCHOOL
# CA2701263          C      A                      PARTINGTON RIDGE MWC
# CA5403031       NTNC      A                      SUN PACIFIC - TULARE
# CA1502465          C      A         PANAMA ROAD PROPERTY OWNERS ASSOC
# CA2702412       NTNC      A                  DOLE FRESH VEGETABLES WS
# CA5000166         NC      A                  FOX GROVE FISHING ACCESS
# CA2300596          C      A      BIG RIVER VISTA MUTUAL WATER COMPANY
# CA3400331          C      A                WESTERNER MOBILE HOME PARK
# CA4990013         RW      A      HEALDSBURG, CITY OF (RECYCLED WATER)
# CA3303095       SSWS      A                          SERVANDO SANCHEZ
# CA4010003          C      A                         SAN MIGUELITO MWC
# CA4500343         NC      A            SHINGLETOWN STORE WATER SYSTEM
# CA4300808       NTNC      A                         O'CONNOR HOSPITAL
# CA3601158         NC      A            HELENDALE CSD COMMUNITY CENTER
# ...              ...    ...                                       ...
# CA3303072       NTNC      A                     GOOSE CREEK GOLF CLUB
# CA4400758       NTNC      A                   RENAISSANCE HIGH SCHOOL
# CA2701280          C      A                               NEPENTHE WS
# CA1500481          C      A                      RIVERNOOK CAMPGROUND
# CA2790005         RW      A  PEBBLE BEACH COMMUNITY SERVICES DISTRICT
# CA4901232       NTNC      A                           LA CREMA WINERY
# CA5601405       NTNC      A                        SANTA CLARA SCHOOL
# CA4400660          C      A                        RANCHO SAN ANDREAS
# CA4200877         NC      A                     BETTERAVIA GAS & MART
# CA3601064       NTNC      A   OMYA CALIFORNIA, A DIVISION OF OMYA INC
# CA5800914         NC      A                   MARYSVILLE RACEWAY PARK
# CA2000535         NC      A                  BEASORE MUTUAL WATER CO.
# CA4500098          C      A                 ANDERSON MOBILE HOME PARK
# CA2000621         NC      A                      MINARETS WORK CENTER
# CA1000507       NTNC      A                   GILLETTE CITRUS COMPANY
# CA1500216          C      A                          OPAL FRY AND SON
# CA5000101       NTNC      A                        CHATOM SCHOOL (EH)
# CA5402030         NC      A                            WAUKENA MARKET
# CA0710300         NC      A                   MOUNT DIABLO STATE PARK
# CA5810004          C      A                         CITY OF WHEATLAND
# CA0707503         NC      A                             BETHEL HARBOR
# CA2702253       SSWS      A                             JAMESBURG MWS
# CA1900035       NTNC      A                            MILLER BREWING
# CA3990011         RW      A              CITY OF TRACY RECYCLED WATER
# CA1000111       NTNC      A                         PINE RIDGE SCHOOL
# CA2000627         NC      A                          BLACK HAWK LODGE
# CA1910023          C      A                             AVERYDALE MWC
# CA4210016          C      A       GOLDEN STATE WATER COMPANY - ORCUTT
# CA4901082         NC      A                           MAZZOCCO WINERY
# CA3601157         NC      A                     APPLEWHITE CAMPGROUND
#
#           water_system_no
# pws_id
# CA3010071       CA3010071
# CA4800564       CA4800564
# CA1503243       CA1503243
# CA3901464       CA3901464
# CA1900868       CA1900868
# CA2490001       CA2490001
# CA1000459       CA1000459
# CA3901368       CA3901368
# CA2900532       CA2900532
# CA4200862       CA4200862
# CA1910028       CA1910028
# CA1910225       CA1910225
# CA4900707       CA4900707
# CA1504004       CA1504004
# CA5690004       CA5690004
# CA0710800       CA0710800
# CA5400538       CA5400538
# CA2701263       CA2701263
# CA5403031       CA5403031
# CA1502465       CA1502465
# CA2702412       CA2702412
# CA5000166       CA5000166
# CA2300596       CA2300596
# CA3400331       CA3400331
# CA4990013       CA4990013
# CA3303095       CA3303095
# CA4010003       CA4010003
# CA4500343       CA4500343
# CA4300808       CA4300808
# CA3601158       CA3601158
# ...                   ...
# CA3303072       CA3303072
# CA4400758       CA4400758
# CA2701280       CA2701280
# CA1500481       CA1500481
# CA2790005       CA2790005
# CA4901232       CA4901232
# CA5601405       CA5601405
# CA4400660       CA4400660
# CA4200877       CA4200877
# CA3601064       CA3601064
# CA5800914       CA5800914
# CA2000535       CA2000535
# CA4500098       CA4500098
# CA2000621       CA2000621
# CA1000507       CA1000507
# CA1500216       CA1500216
# CA5000101       CA5000101
# CA5402030       CA5402030
# CA0710300       CA0710300
# CA5810004       CA5810004
# CA0707503       CA0707503
# CA2702253       CA2702253
# CA1900035       CA1900035
# CA3990011       CA3990011
# CA1000111       CA1000111
# CA2000627       CA2000627
# CA1910023       CA1910023
# CA4210016       CA4210016
# CA4901082       CA4901082
# CA3601157       CA3601157
#
# [8327 rows x 8 columns]

# %%
(d.get_table_water_sources()
)
# Out:
#                                                        name status type_code
# pws_id    entry_id
# CA3010071 0                      IRWD INERCONNECTION TO JTM      A        CC
#           1         MWDSC EOCF NO. 2 TRI-CITIES JTM TREATED      A        CC
#           2            MWDSC SCP SC-5B CONNECTION - TREATED      A        CC
#           3                                        SCWD-GRF      A        CC
# CA4800564 0                                       MAIN WELL      A        WL
#           1                                         WELL 01      A        WL
#           2                                         WELL 02      A        WL
# CA1503243 0                                         WELL 24      A        WL
# CA3901464 0                                         WELL #1      A        WL
# CA1900868 0                                          WELL03      A        WL
#           1                                          WELL01      I        WL
#           2                                          WELL02      I        WL
# CA1000459 0                                   WELL 01 - RAW      A        WL
# CA3901368 0                                         WELL #3      A        WL
#           1                                 WELL #2 (SOUTH)      I        WL
#           2                                          WELL#1      I        WL
# CA2900532 0                                         WELL 06      A        WL
#           1                       WELL 05; PARKING LOT WELL      I        WL
# CA4200862 0                              WELL #1 ANVIL WELL      A        WL
#           1                   WELL #2 FLAG IS UP FARMS WELL      A        WL
# CA1910028 0                           FMWD-BRIGGS - TREATED      A        CC
#           1               FMWD-OCEANVIEW CONNECTION-TREATED      A        CC
#           2              FMWD-PASCHALL CONNECTION - TREATED      A        CC
#           3                                  MWD CONNECTION      A        CC
#           4                                 PICKENS TUNNELS      A        WL
#           5                                         WELL 01      A        WL
#           6                                         WELL 05      A        WL
#           7                                         WELL 07      A        WL
#           8                                         WELL 08      A        WL
#           9                                         WELL 09      A        WL
# ...                                                     ...    ...       ...
# CA1900035 2                                         WELL 01      I        WL
# CA1000111 0                                   WELL-OFF SITE      A        WL
# CA2000627 0                                   SOURCE WELL 1      A        WL
#           1                                          SPRING      I        SP
#           2                              WELL 2 (ABANDONED)      I        WL
# CA1910023 0                                         WELL 01      A        WL
#           1                                         WELL 03      A        WL
#           2                                         WELL 04      A        WL
#           3                                         WELL 05      A        WL
#           4                              WELL 02 - INACTIVE      I        WL
# CA4210016 0                                CRESCENT WELL 01      A        WL
#           1                                 KENNETH WELL 01      A        WL
#           2                                    M.F. WELL 01      A        WL
#           3                                    M.F. WELL 02      A        WL
#           4                                    M.F. WELL 04      A        WL
#           5                                    M.F. WELL 05      A        WL
#           6                                    M.F. WELL 06      A        WL
#           7                                    M.F. WELL 07      A        WL
#           8                                 OAK WELL (1989)      A        WL
#           9                                     ORCUTT WELL      A        WL
#           10                               WOODMERE WELL 01      A        WL
#           11                        WOODMERE WELL 02 (1991)      A        WL
#           12                              EVERGREEN WELL 01      I        WL
#           13                   EVERGREEN WELL 02 - INACTIVE      I        WL
#           14                                   M.F. WELL 03      I        WL
#           15                                OLIVE HILL WELL      I        WL
#           16                 SUNRISE WELL (1987) - INACTIVE      I        WL
# CA4901082 0                                         WELL 02      A        WL
#           1                             WELL 01 - ABANDONED      I        WL
# CA3601157 0                                            WELL      A        WL
#
# [26680 rows x 3 columns]

# %%
(d.get_table_service_connections()
 .sort_values('count', ascending=False)
)
# Out:
#                      count  meter_size_measure meter_type type
# pws_id    entry_id
# CA1910067 3         609694                   0         ME   RS
# CA0110005 0         387846                   0         ME   CB
# CA3710020 3         225109                   0         ME   RS
# CA4310011 2         204733                   0         ME   RS
# CA3810011 0         170509                   0         ME   CB
# CA3410020 0         157312                   0         UN   CB
# CA3310009 0         146850                   0         ME   CB
# CA1010007 0         132981                   0         ME   CB
# CA3310001 0         104188                   0         ME   CB
# CA3010092 4          98901                   0         ME   RS
# CA0110001 0          84730                   0         UN   CB
# CA1910065 3          80271                   0         ME   RS
# CA1510055 0          70062                   0         UN   CB
# CA1510003 0          69810                   0         UN   CB
# CA5010010 0          69306                   0         UN   CB
# CA3310031 0          65447                   0         ME   CB
# CA3010001 0          62615                   0         UN   CB
# CA1910067 1          61362                   0         ME   CM
# CA2110002 0          60585                   0         UN   CB
# CA0710003 0          60334                   0         ME   CB
# CA4910009 0          53599                   0         UN   CB
# CA3010053 0          53020                   0         UN   CB
# CA3710034 0          48747                   0         ME   CB
# CA3910012 0          48674                   0         UN   CB
# CA3010073 3          47278                   0         ME   RS
# CA1910070 2          46922                   0         ME   RS
# CA3710010 3          46763                   0         ME   RS
# CA1910155 3          46625                   0         ME   RS
# CA3410001 0          46318                   0         UN   CB
# CA1510031 0          45038                   0         UN   CB
# ...                    ...                 ...        ...  ...
# CA1502826 0              0                   0         UN   CB
# CA1502033 2              0                   0         ME   IN
# CA1500517 0              0                   0         UN   CB
# CA1502012 2              0                   0         UM   IN
# CA1503672 0              0                   0         UN   CB
#           2              0                   0         UM   IN
# CA1500517 1              0                   0         ME   CM
# CA1502012 0              0                   0         UN   CB
# CA1510302 1              0                   0         UN   CB
# CA1502033 0              0                   0         UN   CB
# CA1502695 0              0                   0         UN   CB
# CA1503230 1              0                   0         UN   CB
# CA1500491 1              0                   0         ME   CM
# CA1502398 2              0                   0         UM   IN
# CA1503270 2              0                   0         UM   IN
#           0              0                   0         UN   CB
# CA1502004 2              0                   0         UM   IN
#           0              0                   0         UN   CB
# CA1503230 3              0                   0         UM   CM
#           4              0                   0         ME   IN
# CA1500491 0              0                   0         UN   CB
# CA1502695 2              0                   0         UM   CM
# CA1510016 1              0                   0         UN   CB
# CA1500449 0              0                   0         UN   CB
# CA1500485 0              0                   0         UN   CB
# CA1502717 0              0                   0         UN   CB
# CA1500571 0              0                   0         UN   CB
#           1              0                   0         UM   CM
# CA1502695 3              0                   0         ME   IN
# CA1503349 0              0                   0         UN   CB
#
# [9592 rows x 4 columns]

# %%
d.get_table_service_areas()
# Out:
#                    code                      name
# pws_id    entry_id
# CA3010071 0           O  WHOLESALER (SELLS WATER)
# CA4800564 0           R          MOBILE HOME PARK
# CA1503243 0          NT   INDUSTRIAL/AGRICULTURAL
# CA3901464 0           O                OTHER AREA
# CA1900868 0           R          MOBILE HOME PARK
# CA2490001 0           O            RECYCLED WATER
# CA1000459 0           O                OTHER AREA
# CA3901368 0          NT   INDUSTRIAL/AGRICULTURAL
# CA2900532 0           T      OTHER TRANSIENT AREA
# CA4200862 0           R          RESIDENTIAL AREA
# CA1910028 0           R          RESIDENTIAL AREA
# CA1910225 0           R          RESIDENTIAL AREA
# CA4900707 0          NT                    SCHOOL
# CA1504004 0          NT   INDUSTRIAL/AGRICULTURAL
# CA5690004 0           O            RECYCLED WATER
# CA0710800 0          NT   INDUSTRIAL/AGRICULTURAL
# CA5400538 0          NT                    SCHOOL
# CA2701263 0           R          RESIDENTIAL AREA
# CA5403031 0          NT   INDUSTRIAL/AGRICULTURAL
# CA1502465 0           R          RESIDENTIAL AREA
# CA2702412 0          NT   INDUSTRIAL/AGRICULTURAL
# CA5000166 0           T           RECREATION AREA
# CA2300596 0           R          RESIDENTIAL AREA
# CA3400331 0           R          MOBILE HOME PARK
# CA4990013 0           O            RECYCLED WATER
# CA4010003 0           R          RESIDENTIAL AREA
# CA4500343 0           T          RETAIL EMPLOYEES
# CA4300808 0          NT          MEDICAL FACILITY
# CA3601158 0           T           RECREATION AREA
# CA3410007 0           R          RESIDENTIAL AREA
# ...                 ...                       ...
# CA3303072 0           T           RECREATION AREA
# CA4400758 0          NT                    SCHOOL
# CA2701280 0           T                RESTAURANT
# CA1500481 0           R          MOBILE HOME PARK
# CA2790005 0           O            RECYCLED WATER
# CA4901232 0           T      OTHER TRANSIENT AREA
# CA5601405 0          NT                    SCHOOL
# CA4400660 0          NT   INDUSTRIAL/AGRICULTURAL
# CA4200877 0           T           SERVICE STATION
# CA3601064 0          NT   INDUSTRIAL/AGRICULTURAL
# CA5800914 0           T      OTHER TRANSIENT AREA
#           1           T           RECREATION AREA
# CA2000535 0           T           RECREATION AREA
# CA4500098 0           R          MOBILE HOME PARK
# CA2000621 0           T      OTHER TRANSIENT AREA
# CA1000507 0          NT   INDUSTRIAL/AGRICULTURAL
# CA1500216 0           R          RESIDENTIAL AREA
# CA5000101 0          NT                    SCHOOL
# CA5402030 0           T      OTHER TRANSIENT AREA
# CA0710300 0           T           RECREATION AREA
# CA5810004 0           O                OTHER AREA
# CA0707503 0           T      OTHER TRANSIENT AREA
# CA1900035 0          NT   INDUSTRIAL/AGRICULTURAL
# CA1000111 0          NT                    SCHOOL
# CA2000627 0           T               HOTEL/MOTEL
# CA1910023 0           R          RESIDENTIAL AREA
# CA4210016 0           R          RESIDENTIAL AREA
# CA4901082 0           T                RESTAURANT
# CA3601157 0           T           RECREATION AREA
#           1           T               SUMMER CAMP
#
# [8360 rows x 2 columns]

# %%
(d.get_table_water_purchases()
 .reset_index()
 .groupby('seller_water_system_no')
 .agg({'water_system_name': 'first', 'pws_id': 'count'})
 .rename(columns={'pws_id': 'buyer_count'})
 .sort_values('buyer_count', ascending=False)
)
# Out:
#                                                water_system_name  buyer_count
# seller_water_system_no
# CA1910087                   METROPOLITAN WATER DIST. OF SO. CAL.          345
# CA3710042                       SAN DIEGO COUNTY WATER AUTHORITY           77
# CA3810001                    SAN FRANCISCO REGIONAL WATER SYSTEM           62
# CA4310027                      SANTA CLARA VALLEY WATER DISTRICT           31
# CA1910045                 ANTELOPE VALLEY-EAST KERN WATER AGENCY           29
# CA3710020                                     SAN DIEGO, CITY OF           27
# CA1910199                      CALIFORNIA DOMESTIC WATER COMPANY           25
# CA3310009                                   EASTERN MUNICIPAL WD           22
# CA5610050                         CALLEGUAS MUNICIPAL WATER DIST           21
# CA4310011                                         SAN JOSE WATER           20
# CA1310014                           IMPERIAL IRRIGATION DISTRICT           19
# CA3010071                     JOINT REGIONAL WATER SUPPLY SYSTEM           19
# CA1910048               SANTA CLARITA VALLEY W.A.-IMPORTED DIVIS           19
# CA4210030                          CENTRAL COAST WATER AUTHORITY           18
# CA3710034                                    OTAY WATER DISTRICT           17
# CA1910041                                      THREE VALLEYS MWD           17
# CA3010093                             EAST ORANGE COUNTY WD - WZ           16
# CA3710010                                   HELIX WATER DISTRICT           14
# CA4910020                             SONOMA COUNTY WATER AGENCY           14
# CA5610046                                   UNITED WTR CONS DIST           12
# CA3610114                                                  CLAWA           11
# CA5610024                           CASITAS MUNICIPAL WATER DIST           10
# CA3710025                                   SWEETWATER AUTHORITY           10
# CA3010003                                     CITY OF BUENA PARK            9
# CA3710037                                          PADRE DAM MWD            9
# CA1910032                         FOOTHILL MUNICIPAL WATER DIST.            9
# CA0710003                            CONTRA COSTA WATER DISTRICT            9
# CA3310021                                    JURUPA COMMUNITY SD            9
# CA1510053                ANTELOPE VALLEY E KERN WTR AGY-ROSAMOND            8
# CA0910001                                    EL DORADO ID - MAIN            8
# ...                                                          ...          ...
# CA1910001                                       CITY OF ALHAMBRA            1
# CA1900912                               GORMAN ELEMENTARY SCHOOL            1
# CA3610086                    WEST END CONSOLIDATED WATER COMPANY            1
# CA3610110                                     ARROWBEAR PARK CWD            1
# CA1900849                            LLANO DEL RIO WATER COMPANY            1
# CA3610120                                 PHELAN PINON HILLS CSD            1
# CA3610850                         CALIFORNIA INSTITUTION FOR MEN            1
# CA1900767                 GOLDEN VALLEY MUNICIPAL WATER DISTRICT            1
# CA1900587                                       USFS CLEAR CREEK            1
# CA3010036                                   CITY OF SAN CLEMENTE            1
# CA1710006                          KONOCTI COUNTY WATER DISTRICT            1
# CA1910005               LOS ANGELES CO WW DIST 40 REG 38 LAKE LA            1
# CA1910007                                  AZUSA LIGHT AND WATER            1
# CA3610044                          DWP - BIG BEAR LAKE/MOONRIDGE            1
# CA1910052                   CAL/AM WATER COMPANY - BALDWIN HILLS            1
# CA1910124                             PASADENA-CITY, WATER DEPT.            1
# CA1910102                                   PALMDALE WATER DIST.            1
# CA1910070                LOS ANGELES CO WW DIST 4 & 34-LANCASTER            1
# CA3510001                                     HOLLISTER, CITY OF            1
# CA3510002                             SAN JUAN BAUTISTA, CITY OF            1
# CA3610001                                      ADELANTO, CITY OF            1
# CA1910034                             DOWNEY - CITY, WATER DEPT.            1
# CA3610043                        GOLDEN STATE WATER CO - BARSTOW            1
# CA3610009                     BIGHORN - DESERT VIEW WATER AGENCY            1
# CA3610018                        CUCAMONGA VALLEY WATER DISTRICT            1
# CA1910025                 LOS ANGELES CWWD 40 REG. 39-ROCK CREEK            1
# CA3610036                                   CHINO HILLS, CITY OF            1
# CA1910019                           CERRITOS - CITY, WATER DEPT.            1
# CA1910017                SANTA CLARITA VALLEY W.A.-SANTA CLARITA            1
# CA5710012                      WOODLAND-DAVIS CLEAN WATER AGENCY            1
#
# [265 rows x 2 columns]

# %%
from config import PATH_RESULTS

PATH_RESULTS
# Out:
# PosixPath('data/results')

# %%
d.to_csv(PATH_RESULTS)
